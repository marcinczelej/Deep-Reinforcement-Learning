# %%
import gym
from model import Network
import numpy as np
from sharedOptimizer import sharedAdam
import time
import torch
import torch.multiprocessing as mp
from train import train
from test import test
import os
os.environ["OMP_NUM_THREADS"] = "1"

class params:
    env_name = "BipedalWalker-v2"
    n_steps = 20
    gamma = 0.99
    tau = 0.98
    lr = 0.0001
    seed = 1
    processes_amount = 8
    max_episode_length = 10000
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    solved_score = 300

torch.manual_seed(params.seed)
env = gym.make(params.env_name)
print("observation = ", env.observation_space.shape[0])
print("action_space = ", env.action_space)
shared_model = Network(env.observation_space.shape[0], env.action_space, params.device).to(params.device)
shared_model.share_memory()
shared_optimizer = sharedAdam(shared_model.parameters(), lr = params.lr)
shared_optimizer.share_memory()

processes = []
p = mp.Process(target=test, args=(params,shared_model))
p.start()
processes.append(p)
time.sleep(0.2)

for i in range(params.processes_amount):
    p = mp.Process(target=train, args=(i, params, shared_model, shared_optimizer))
    p.start()
    processes.append(p)
    time.sleep(0.2)
for p in processes:
    time.sleep(0.2)
    p.join()
# Out:
# observation =  24
# action_space =  Box(4,)
# 1 |reward: -92.78383858662262 |last: -92.78383858662262 |max_reward: -10000000 |ts: 129
#    NEW MAX saving model   : -92.78383858662262
# 2 |reward: -95.65511255413 |last: -94.21947557037632 |max_reward: -92.78383858662262 |ts: 64
# 3 |reward: -98.87333396780615 |last: -95.77076170285294 |max_reward: -92.78383858662262 |ts: 52
# 4 |reward: -97.45703842091126 |last: -96.19233088236751 |max_reward: -92.78383858662262 |ts: 62
# 5 |reward: -88.9502358278508 |last: -94.74391187146418 |max_reward: -92.78383858662262 |ts: 119
#    NEW MAX saving model   : -88.9502358278508
# 6 |reward: -97.41759426993504 |last: -95.18952560454265 |max_reward: -88.9502358278508 |ts: 109
# 7 |reward: -78.57239983331958 |last: -92.81565049436792 |max_reward: -88.9502358278508 |ts: 246
#    NEW MAX saving model   : -78.57239983331958
# 8 |reward: -80.1994153552815 |last: -91.23862110198212 |max_reward: -78.57239983331958 |ts: 159
# 9 |reward: -99.65373816242565 |last: -92.17363410869807 |max_reward: -78.57239983331958 |ts: 112
# 10 |reward: -86.4608770159716 |last: -91.60235839942541 |max_reward: -78.57239983331958 |ts: 230
# 11 |reward: -96.4245868924884 |last: -92.04074280788569 |max_reward: -78.57239983331958 |ts: 68
# Process Process-1:
# Process Process-2:
# Process Process-6:
# Traceback (most recent call last):
#   File "/home/mizzmir/anaconda3/envs/deep_reinforcement/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Process Process-5:
# Traceback (most recent call last):
#   File "/home/mizzmir/anaconda3/envs/deep_reinforcement/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/mizzmir/Projekty/continuous a3c/nowe_podejscie/test.py", line 59, in test
#     time.sleep(60)
#   File "/home/mizzmir/anaconda3/envs/deep_reinforcement/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# KeyboardInterrupt
#   File "/home/mizzmir/anaconda3/envs/deep_reinforcement/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/mizzmir/anaconda3/envs/deep_reinforcement/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Process Process-4:
#   File "/home/mizzmir/Projekty/continuous a3c/nowe_podejscie/train.py", line 65, in train
#     log_probs.append(log_prob)
#   File "/home/mizzmir/anaconda3/envs/deep_reinforcement/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/mizzmir/Projekty/continuous a3c/nowe_podejscie/train.py", line 28, in CalculateDistribution
#     return action, log_prob, entropy, mu, value
#   File "/home/mizzmir/anaconda3/envs/deep_reinforcement/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# KeyboardInterrupt
#   File "/home/mizzmir/Projekty/continuous a3c/nowe_podejscie/train.py", line 103, in train
# Process Process-3:
#   File "/home/mizzmir/anaconda3/envs/deep_reinforcement/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/home/mizzmir/Projekty/continuous a3c/nowe_podejscie/train.py", line 70, in train
#     reward = max(min(reward, 1), -1)
# Traceback (most recent call last):
#   File "/home/mizzmir/anaconda3/envs/deep_reinforcement/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/mizzmir/anaconda3/envs/deep_reinforcement/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Process Process-7:
#   File "/home/mizzmir/Projekty/continuous a3c/nowe_podejscie/sharedOptimizer.py", line 56, in step
#     exp_avg.mul_(beta1).add_(1 - beta1, grad)
#   File "/home/mizzmir/anaconda3/envs/deep_reinforcement/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/mizzmir/anaconda3/envs/deep_reinforcement/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# KeyboardInterrupt
#   File "/home/mizzmir/Projekty/continuous a3c/nowe_podejscie/train.py", line 98, in train
#     for param, shared_param in zip(model.parameters(), shared_model.parameters()):
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/home/mizzmir/anaconda3/envs/deep_reinforcement/lib/python3.7/site-packages/torch/tensor.py", line 102, in backward
#     torch.autograd.backward(self, gradient, retain_graph, create_graph)
#   File "/home/mizzmir/anaconda3/envs/deep_reinforcement/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/mizzmir/anaconda3/envs/deep_reinforcement/lib/python3.7/site-packages/torch/autograd/__init__.py", line 90, in backward
#     allow_unreachable=True)  # allow_unreachable flag
#   File "/home/mizzmir/anaconda3/envs/deep_reinforcement/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# KeyboardInterrupt
#   File "/home/mizzmir/Projekty/continuous a3c/nowe_podejscie/train.py", line 98, in train
#     for param, shared_param in zip(model.parameters(), shared_model.parameters()):
#   File "/home/mizzmir/Projekty/continuous a3c/nowe_podejscie/train.py", line 98, in train
#     for param, shared_param in zip(model.parameters(), shared_model.parameters()):
#   File "/home/mizzmir/anaconda3/envs/deep_reinforcement/lib/python3.7/site-packages/torch/tensor.py", line 102, in backward
#     torch.autograd.backward(self, gradient, retain_graph, create_graph)
#   File "/home/mizzmir/anaconda3/envs/deep_reinforcement/lib/python3.7/site-packages/torch/tensor.py", line 102, in backward
#     torch.autograd.backward(self, gradient, retain_graph, create_graph)
#   File "/home/mizzmir/anaconda3/envs/deep_reinforcement/lib/python3.7/site-packages/torch/autograd/__init__.py", line 90, in backward
#     allow_unreachable=True)  # allow_unreachable flag
#   File "/home/mizzmir/anaconda3/envs/deep_reinforcement/lib/python3.7/site-packages/torch/autograd/__init__.py", line 90, in backward
#     allow_unreachable=True)  # allow_unreachable flag
# KeyboardInterrupt
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-804cf762c9a1> in <module>
#      45 for p in processes:
#      46     time.sleep(0.2)
# ---> 47     p.join()
#
# ~/anaconda3/envs/deep_reinforcement/lib/python3.7/multiprocessing/process.py in join(self, timeout)
#     138         assert self._parent_pid == os.getpid(), 'can only join a child process'
#     139         assert self._popen is not None, 'can only join a started process'
# --> 140         res = self._popen.wait(timeout)
#     141         if res is not None:
#     142             _children.discard(self)
#
# ~/anaconda3/envs/deep_reinforcement/lib/python3.7/multiprocessing/popen_fork.py in wait(self, timeout)
#      46                     return None
#      47             # This shouldn't block if wait() returned successfully.
# ---> 48             return self.poll(os.WNOHANG if timeout == 0.0 else 0)
#      49         return self.returncode
#      50
#
# ~/anaconda3/envs/deep_reinforcement/lib/python3.7/multiprocessing/popen_fork.py in poll(self, flag)
#      26         if self.returncode is None:
#      27             try:
# ---> 28                 pid, sts = os.waitpid(self.pid, flag)
#      29             except OSError as e:
#      30                 # Child process not yet created. See #1731717
#
# KeyboardInterrupt:
