# %%
import time
from model import a3cNetwork
import numpy as np
from sharedOptimizer import sharedAdam
from utility import *
from train import train
from test import test

import torch
import torch.multiprocessing as mp

class params:
    seed = 4
    action_space = len(actions)
    n_steps = 15
    gamma = 0.99
    tau = 0.95
    lr = 0.0001
    number_of_processes = 1
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    solved_score = 1500

# %%
shared_model = a3cNetwork(params.action_space)
shared_model.share_memory()

shared_optimizer = sharedAdam(shared_model.parameters(), lr = params.lr)

processes = []
p = mp.Process(target = test, args = (params, shared_model))
p.start()
processes.append(p)

for i in range(params.number_of_processes):
    p = mp.Process(target = train, args = (i, params, shared_model, shared_optimizer))
    p.start()
    processes.append(p)
    time.sleep(0.2)
for i in range(len(processes)):
    p.join()
    time.sleep(0.2)
# Out:
# Process Process-1:
# Traceback (most recent call last):
#   File "/home/mizzmir/anaconda3/envs/deep_reinforcement/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/mizzmir/anaconda3/envs/deep_reinforcement/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/mizzmir/git_clony/deep_reinforcement_learning/Deep-Reinforcement-Learning/Vizdoom_agents/A3C agent deadly Corridor/test.py", line 20, in test
#     img = preprocess_frame(img).to(params.device)
#   File "/home/mizzmir/git_clony/deep_reinforcement_learning/Deep-Reinforcement-Learning/Vizdoom_agents/A3C agent deadly Corridor/utility.py", line 14, in preprocess_frame
#     normalized_frame = cropped_frame/255.0
# NameError: name 'cropped_frame' is not defined
# Process Process-2:
# Traceback (most recent call last):
#   File "/home/mizzmir/anaconda3/envs/deep_reinforcement/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/mizzmir/anaconda3/envs/deep_reinforcement/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/mizzmir/git_clony/deep_reinforcement_learning/Deep-Reinforcement-Learning/Vizdoom_agents/A3C agent deadly Corridor/train.py", line 25, in train
#     img = preprocess_frame(img).to(params.device)
#   File "/home/mizzmir/git_clony/deep_reinforcement_learning/Deep-Reinforcement-Learning/Vizdoom_agents/A3C agent deadly Corridor/utility.py", line 14, in preprocess_frame
#     normalized_frame = cropped_frame/255.0
# NameError: name 'cropped_frame' is not defined
# Process Process-3:
# Traceback (most recent call last):
#   File "/home/mizzmir/anaconda3/envs/deep_reinforcement/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/mizzmir/anaconda3/envs/deep_reinforcement/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/mizzmir/git_clony/deep_reinforcement_learning/Deep-Reinforcement-Learning/Vizdoom_agents/A3C agent deadly Corridor/train.py", line 25, in train
#     img = preprocess_frame(img).to(params.device)
#   File "/home/mizzmir/git_clony/deep_reinforcement_learning/Deep-Reinforcement-Learning/Vizdoom_agents/A3C agent deadly Corridor/utility.py", line 14, in preprocess_frame
#     normalized_frame = cropped_frame/255.0
# NameError: name 'cropped_frame' is not defined
# Process Process-4:
# Traceback (most recent call last):
#   File "/home/mizzmir/anaconda3/envs/deep_reinforcement/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/mizzmir/anaconda3/envs/deep_reinforcement/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/mizzmir/git_clony/deep_reinforcement_learning/Deep-Reinforcement-Learning/Vizdoom_agents/A3C agent deadly Corridor/train.py", line 25, in train
#     img = preprocess_frame(img).to(params.device)
#   File "/home/mizzmir/git_clony/deep_reinforcement_learning/Deep-Reinforcement-Learning/Vizdoom_agents/A3C agent deadly Corridor/utility.py", line 14, in preprocess_frame
#     normalized_frame = cropped_frame/255.0
# NameError: name 'cropped_frame' is not defined
# Process Process-5:
# Traceback (most recent call last):
#   File "/home/mizzmir/anaconda3/envs/deep_reinforcement/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/mizzmir/anaconda3/envs/deep_reinforcement/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/mizzmir/git_clony/deep_reinforcement_learning/Deep-Reinforcement-Learning/Vizdoom_agents/A3C agent deadly Corridor/train.py", line 25, in train
#     img = preprocess_frame(img).to(params.device)
#   File "/home/mizzmir/git_clony/deep_reinforcement_learning/Deep-Reinforcement-Learning/Vizdoom_agents/A3C agent deadly Corridor/utility.py", line 14, in preprocess_frame
#     normalized_frame = cropped_frame/255.0
# NameError: name 'cropped_frame' is not defined
# Process Process-6:
# Traceback (most recent call last):
#   File "/home/mizzmir/anaconda3/envs/deep_reinforcement/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/mizzmir/anaconda3/envs/deep_reinforcement/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/mizzmir/git_clony/deep_reinforcement_learning/Deep-Reinforcement-Learning/Vizdoom_agents/A3C agent deadly Corridor/train.py", line 25, in train
#     img = preprocess_frame(img).to(params.device)
#   File "/home/mizzmir/git_clony/deep_reinforcement_learning/Deep-Reinforcement-Learning/Vizdoom_agents/A3C agent deadly Corridor/utility.py", line 14, in preprocess_frame
#     normalized_frame = cropped_frame/255.0
# NameError: name 'cropped_frame' is not defined
# Process Process-7:
# Traceback (most recent call last):
#   File "/home/mizzmir/anaconda3/envs/deep_reinforcement/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/mizzmir/anaconda3/envs/deep_reinforcement/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/mizzmir/git_clony/deep_reinforcement_learning/Deep-Reinforcement-Learning/Vizdoom_agents/A3C agent deadly Corridor/train.py", line 25, in train
#     img = preprocess_frame(img).to(params.device)
#   File "/home/mizzmir/git_clony/deep_reinforcement_learning/Deep-Reinforcement-Learning/Vizdoom_agents/A3C agent deadly Corridor/utility.py", line 14, in preprocess_frame
#     normalized_frame = cropped_frame/255.0
# NameError: name 'cropped_frame' is not defined
# Process Process-8:
# Traceback (most recent call last):
#   File "/home/mizzmir/anaconda3/envs/deep_reinforcement/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/mizzmir/anaconda3/envs/deep_reinforcement/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/mizzmir/git_clony/deep_reinforcement_learning/Deep-Reinforcement-Learning/Vizdoom_agents/A3C agent deadly Corridor/train.py", line 25, in train
#     img = preprocess_frame(img).to(params.device)
#   File "/home/mizzmir/git_clony/deep_reinforcement_learning/Deep-Reinforcement-Learning/Vizdoom_agents/A3C agent deadly Corridor/utility.py", line 14, in preprocess_frame
#     normalized_frame = cropped_frame/255.0
# NameError: name 'cropped_frame' is not defined
# Process Process-9:
# Traceback (most recent call last):
#   File "/home/mizzmir/anaconda3/envs/deep_reinforcement/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/mizzmir/anaconda3/envs/deep_reinforcement/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/mizzmir/git_clony/deep_reinforcement_learning/Deep-Reinforcement-Learning/Vizdoom_agents/A3C agent deadly Corridor/train.py", line 25, in train
#     img = preprocess_frame(img).to(params.device)
#   File "/home/mizzmir/git_clony/deep_reinforcement_learning/Deep-Reinforcement-Learning/Vizdoom_agents/A3C agent deadly Corridor/utility.py", line 14, in preprocess_frame
#     normalized_frame = cropped_frame/255.0
# NameError: name 'cropped_frame' is not defined
